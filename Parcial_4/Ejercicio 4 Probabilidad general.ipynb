# %%
import matplotlib.pyplot as plt
prob=1
for i in range(365):
  prob*=(365-(i+1))/365  
print(prob)

chart=[]

pp=1
pps=[]
n=[]
for i in range(81):
  pp*=(365-(i+1))/365
  pps.append([pp])
  n.append([i])

plt.scatter(n,pps,color="r")
# Out:
# 0.0
